# %%
import pandas as pd

# %%
train = pd.read_csv(
    "/Users/rishikarandev/deep learning/ECE685D_FinalProject/CheXpert-v1.0-small/train.csv"
)

# %%
# Check values & NAs for all label columns
for col in train.columns[4:]:
    print(train[col].value_counts(), "\nNAs: ", train[col].isnull().sum(), "\n\n")
# Out:
# AP/PA
# AP    161590
# PA     29420
# LL        16
# RL         1
# Name: count, dtype: int64
# NAs:  32387
#
#
# No Finding
# 1.0    22381
# Name: count, dtype: int64
# NAs:  201033
#
#
# Enlarged Cardiomediastinum
#  0.0    21638
# -1.0    12403
#  1.0    10798
# Name: count, dtype: int64
# NAs:  178575
#
#
# Cardiomegaly
#  1.0    27000
#  0.0    11116
# -1.0     8087
# Name: count, dtype: int64
# NAs:  177211
#
#
# Lung Opacity
#  1.0    105581
#  0.0      6599
# -1.0      5598
# Name: count, dtype: int64
# NAs:  105636
#
#
# Lung Lesion
#  1.0    9186
# -1.0    1488
#  0.0    1270
# Name: count, dtype: int64
# NAs:  211470
#
#
# Edema
#  1.0    52246
#  0.0    20726
# -1.0    12984
# Name: count, dtype: int64
# NAs:  137458
#
#
# Consolidation
#  0.0    28097
# -1.0    27742
#  1.0    14783
# Name: count, dtype: int64
# NAs:  152792
#
#
# Pneumonia
# -1.0    18770
#  1.0     6039
#  0.0     2799
# Name: count, dtype: int64
# NAs:  195806
#
#
# Atelectasis
# -1.0    33739
# ...

# %%
train.shape
# Out:
# (223414, 19)

# %%
# Samples that are missing all labels
train.loc[train.isnull().sum(axis=1) == 15, :]
# Out:
#                                                      Path     Sex  Age  \
# 122760  CheXpert-v1.0-small/train/patient29422/study3/...  Female   50
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 122760         Lateral   NaN         NaN                         NaN
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  Edema  Consolidation  \
# 122760           NaN           NaN          NaN    NaN            NaN
#
#         Pneumonia  Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  \
# 122760        NaN          NaN           NaN               NaN            NaN
#
#         Fracture  Support Devices
# 122760       NaN              NaN

# %%
train.drop("AP/PA", axis=1).iloc[1]
# Out:
# Path                          CheXpert-v1.0-small/train/patient00002/study2/...
# Sex                                                                      Female
# Age                                                                          87
# Frontal/Lateral                                                         Frontal
# No Finding                                                                  NaN
# Enlarged Cardiomediastinum                                                  NaN
# Cardiomegaly                                                               -1.0
# Lung Opacity                                                                1.0
# Lung Lesion                                                                 NaN
# Edema                                                                      -1.0
# Consolidation                                                              -1.0
# Pneumonia                                                                   NaN
# ...

# %%
train.drop("AP/PA", axis=1).iloc[1, 5:]
# Out:
# Enlarged Cardiomediastinum    NaN
# Cardiomegaly                 -1.0
# Lung Opacity                  1.0
# Lung Lesion                   NaN
# Edema                        -1.0
# Consolidation                -1.0
# Pneumonia                     NaN
# Atelectasis                  -1.0
# Pneumothorax                  NaN
# Pleural Effusion             -1.0
# Pleural Other                 NaN
# Fracture                      1.0
# Support Devices               NaN
# Name: 1, dtype: object

# %%
valid = pd.read_csv(
    "/Users/rishikarandev/deep learning/ECE685D_FinalProject/CheXpert-v1.0-small/valid.csv"
)
valid.loc[valid.isnull().sum(axis=1) == 15, :]
# Out:
# Empty DataFrame
# Columns: [Path, Sex, Age, Frontal/Lateral, AP/PA, No Finding, Enlarged Cardiomediastinum, Cardiomegaly, Lung Opacity, Lung Lesion, Edema, Consolidation, Pneumonia, Atelectasis, Pneumothorax, Pleural Effusion, Pleural Other, Fracture, Support Devices]
# Index: []

# %%
normal = train.loc[train["No Finding"] == 1]

for col in normal.columns[7:]:
    print(normal[col].value_counts())
    print("NAs: ", normal[col].isnull().sum(), "\n")
# Out:
# Cardiomegaly
# 0.0    3350
# Name: count, dtype: int64
# NAs:  19031
#
# Lung Opacity
# 0.0    2421
# Name: count, dtype: int64
# NAs:  19960
#
# Lung Lesion
# 0.0    377
# Name: count, dtype: int64
# NAs:  22004
#
# Edema
# 0.0    4461
# Name: count, dtype: int64
# NAs:  17920
#
# Consolidation
# 0.0    8836
# Name: count, dtype: int64
# NAs:  13545
#
# Pneumonia
# 0.0    1158
# Name: count, dtype: int64
# NAs:  21223
#
# Atelectasis
# 0.0    483
# Name: count, dtype: int64
# NAs:  21898
#
# Pneumothorax
# 0.0    13411
# Name: count, dtype: int64
# NAs:  8970
#
# Pleural Effusion
# 0.0    11450
# Name: count, dtype: int64
# NAs:  10931
#
# Pleural Other
# 0.0    20
# Name: count, dtype: int64
# NAs:  22361
#
# Fracture
# 0.0    1091
# Name: count, dtype: int64
# NAs:  21290
#
# Support Devices
#  1.0    8808
#  0.0     671
# -1.0     110
# Name: count, dtype: int64
# NAs:  12792
